# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # Note
# just change the path to do the cleaning for training and testing dataset. You could skip wrong data part cuz in my running results, the datasets do not have wrong data issue.

# %% [markdown]
# # Data cleaning

# %%
df = pd.read_csv('/Users/eva/Documents/Study/Y1S2/DMT/assignment2/training_set_VU_DM.csv')
df['date_time'] = pd.to_datetime(df['date_time'])
df.head()
# Out:
#    srch_id           date_time  site_id  visitor_location_country_id  \
# 0        1 2013-04-04 08:32:15       12                          187
# 1        1 2013-04-04 08:32:15       12                          187
# 2        1 2013-04-04 08:32:15       12                          187
# 3        1 2013-04-04 08:32:15       12                          187
# 4        1 2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score  ...  comp6_rate_percent_diff  \
# 0                3                3.5  ...                      NaN
# 1                4                4.0  ...                      NaN
# 2                3                4.5  ...                      NaN
# 3                2                4.0  ...                      NaN
# 4                4                3.5  ...                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff  click_bool  gross_bookings_usd  booking_bool
# 0                      NaN           0                 NaN             0
# 1                      NaN           0                 NaN             0
# 2                      NaN           0                 NaN             0
# 3                      5.0           0                 NaN             0
# 4                      NaN           0                 NaN             0
#
# [5 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['srch_id', 'date_time', 'site_id', 'visitor_location_country_id',
#        'visitor_hist_starrating', 'visitor_hist_adr_usd', 'prop_country_id',
#        'prop_id', 'prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'position', 'price_usd', 'promotion_flag',
#        'srch_destination_id', 'srch_length_of_stay', 'srch_booking_window',
#        'srch_adults_count', 'srch_children_count', 'srch_room_count',
#        'srch_saturday_night_bool', 'srch_query_affinity_score',
#        'orig_destination_distance', 'random_bool', 'comp1_rate', 'comp1_inv',
#        'comp1_rate_percent_diff', 'comp2_rate', 'comp2_inv',
#        'comp2_rate_percent_diff', 'comp3_rate', 'comp3_inv',
#        'comp3_rate_percent_diff', 'comp4_rate', 'comp4_inv',
#        'comp4_rate_percent_diff', 'comp5_rate', 'comp5_inv',
#        'comp5_rate_percent_diff', 'comp6_rate', 'comp6_inv',
#        'comp6_rate_percent_diff', 'comp7_rate', 'comp7_inv',
#        'comp7_rate_percent_diff', 'comp8_rate', 'comp8_inv',
#        'comp8_rate_percent_diff', 'click_bool', 'gross_bookings_usd',
#        'booking_bool'],
#       dtype='object')

# %% [markdown]
# ## Wrong data

# %%
# Plot the disribution of all columns except _id variables And price_usd

df_filtered = df.loc[:, ~df.columns.str.contains('_id') & (df.columns != 'price_usd')]

# %%
# takes a long time to run especially for price_usd.
sns.set(style='whitegrid')

for column in df_filtered.columns:
    print(column)
    plt.figure(figsize=(10, 4))
    sns.histplot(df_filtered[column].dropna(), kde=False)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
    print(df[column].describe())
# Out:
# date_time
# count                          4958347
# mean     2013-03-11 06:19:37.890842880
# min                2012-11-01 00:08:29
# 25%                2013-01-14 17:47:32
# 50%                2013-03-13 20:13:18
# 75%                2013-05-10 00:01:38
# max                2013-06-30 23:58:24
# Name: date_time, dtype: object
# visitor_hist_starrating
# count    251866.000000
# mean          3.374334
# std           0.692519
# min           1.410000
# 25%           2.920000
# 50%           3.450000
# 75%           3.930000
# max           5.000000
# Name: visitor_hist_starrating, dtype: float64
# visitor_hist_adr_usd
# count    252988.000000
# mean        176.022659
# std         107.254493
# min           0.000000
# 25%         109.810000
# 50%         152.240000
# 75%         213.490000
# max        1958.700000
# Name: visitor_hist_adr_usd, dtype: float64
# prop_starrating
# count    4.958347e+06
# mean     3.180525e+00
# std      1.051024e+00
# min      0.000000e+00
# 25%      3.000000e+00
# 50%      3.000000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: prop_starrating, dtype: float64
# prop_review_score
# count    4.950983e+06
# mean     3.777777e+00
# std      1.050329e+00
# min      0.000000e+00
# 25%      3.500000e+00
# 50%      4.000000e+00
# 75%      4.500000e+00
# max      5.000000e+00
# Name: prop_review_score, dtype: float64
# prop_brand_bool
# count    4.958347e+06
# mean     6.346994e-01
# std      4.815144e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: prop_brand_bool, dtype: float64
# prop_location_score1
# count    4.958347e+06
# mean     2.872589e+00
# std      1.531011e+00
# min      0.000000e+00
# 25%      1.790000e+00
# 50%      2.770000e+00
# 75%      4.040000e+00
# max      6.980000e+00
# Name: prop_location_score1, dtype: float64
# prop_location_score2
# count    3.867999e+06
# mean     1.303852e-01
# std      1.594634e-01
# min      0.000000e+00
# 25%      1.900000e-02
# 50%      6.900000e-02
# 75%      1.805000e-01
# max      1.000000e+00
# Name: prop_location_score2, dtype: float64
# prop_log_historical_price
# count    4.958347e+06
# mean     4.317913e+00
# std      1.834869e+00
# min      0.000000e+00
# 25%      4.450000e+00
# 50%      4.910000e+00
# 75%      5.310000e+00
# max      6.210000e+00
# Name: prop_log_historical_price, dtype: float64
# position
# count    4.958347e+06
# mean     1.685624e+01
# std      1.042566e+01
# min      1.000000e+00
# 25%      8.000000e+00
# 50%      1.600000e+01
# 75%      2.600000e+01
# max      4.000000e+01
# Name: position, dtype: float64
# promotion_flag
# count    4.958347e+06
# mean     2.156198e-01
# std      4.112517e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: promotion_flag, dtype: float64
# srch_length_of_stay
# count    4.958347e+06
# mean     2.385427e+00
# std      2.053243e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      5.700000e+01
# Name: srch_length_of_stay, dtype: float64
# srch_booking_window
# count    4.958347e+06
# mean     3.747417e+01
# std      5.199341e+01
# min      0.000000e+00
# 25%      4.000000e+00
# 50%      1.700000e+01
# 75%      4.800000e+01
# max      4.920000e+02
# Name: srch_booking_window, dtype: float64
# srch_adults_count
# count    4.958347e+06
# mean     1.972637e+00
# std      8.570628e-01
# min      1.000000e+00
# 25%      2.000000e+00
# 50%      2.000000e+00
# 75%      2.000000e+00
# max      9.000000e+00
# Name: srch_adults_count, dtype: float64
# srch_children_count
# count    4.958347e+06
# mean     3.504918e-01
# std      7.325692e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.000000e+00
# Name: srch_children_count, dtype: float64
# srch_room_count
# count    4.958347e+06
# mean     1.110525e+00
# std      4.172290e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      8.000000e+00
# Name: srch_room_count, dtype: float64
# srch_saturday_night_bool
# count    4.958347e+06
# mean     5.022127e-01
# std      4.999952e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: srch_saturday_night_bool, dtype: float64
# srch_query_affinity_score
# count    317406.000000
# mean        -24.146418
# std          15.743238
# min        -326.567500
# 25%         -30.774775
# 50%         -20.451300
# 75%         -13.350625
# max          -2.494100
# Name: srch_query_affinity_score, dtype: float64
# orig_destination_distance
# count    3.350565e+06
# mean     1.301234e+03
# std      2.023951e+03
# min      1.000000e-02
# 25%      1.398000e+02
# 50%      3.866000e+02
# 75%      1.500670e+03
# max      1.166664e+04
# Name: orig_destination_distance, dtype: float64
# random_bool
# count    4.958347e+06
# mean     2.959004e-01
# std      4.564465e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: random_bool, dtype: float64
# comp1_rate
# count    119930.000000
# mean          0.479788
# std           0.641565
# min          -1.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: comp1_rate, dtype: float64
# comp1_inv
# count    129559.000000
# mean          0.031059
# std           0.229688
# min          -1.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: comp1_inv, dtype: float64
# comp1_rate_percent_diff
# count    94439.000000
# mean       244.229916
# std       1165.448634
# min          2.000000
# 25%          7.000000
# 50%         10.000000
# 75%         16.000000
# max      30389.000000
# Name: comp1_rate_percent_diff, dtype: float64
# comp2_rate
# count    2.024672e+06
# mean     4.418987e-02
# std      4.484236e-01
# min     -1.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: comp2_rate, dtype: float64
# comp2_inv
# count    2.130269e+06
# mean     3.931006e-02
# std      2.342388e-01
# min     -1.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: comp2_inv, dtype: float64
# comp2_rate_percent_diff
# count    556238.000000
# mean         18.490732
# std         240.113851
# min           2.000000
# 25%           7.000000
# 50%          11.000000
# 75%          20.000000
# max      168893.000000
# Name: comp2_rate_percent_diff, dtype: float64
# comp3_rate
# count    1.534288e+06
# mean     1.729010e-02
# std      4.575808e-01
# min     -1.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: comp3_rate, dtype: float64
# comp3_inv
# count    1.650990e+06
# mean     5.776897e-02
# std      2.948202e-01
# min     -1.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: comp3_inv, dtype: float64
# comp3_rate_percent_diff
# count    472797.000000
# mean         27.071559
# std        1012.919911
# min           2.000000
# 25%           7.000000
# 50%          11.000000
# 75%          18.000000
# max      199266.000000
# Name: comp3_rate_percent_diff, dtype: float64
# comp4_rate
# count    307378.000000
# mean         -0.016543
# std           0.578718
# min          -1.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: comp4_rate, dtype: float64
# comp4_inv
# count    343663.000000
# mean          0.096653
# std           0.337165
# min          -1.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: comp4_inv, dtype: float64
# comp4_rate_percent_diff

# %%
# make price_usd interger by rounding to the closest integer
df['price_usd'] = df['price_usd'].apply(lambda x: np.round(x))
df['price_usd'] = df['price_usd'].astype(int)

# %%
# 接着跑后五列
for column in df_filtered.columns[30:]:
    print(column)
# Out:
# comp4_inv
# comp4_rate_percent_diff
# comp5_rate
# comp5_inv
# comp5_rate_percent_diff
# comp6_rate
# comp6_inv
# comp6_rate_percent_diff
# comp7_rate
# comp7_inv
# comp7_rate_percent_diff
# comp8_rate
# comp8_inv
# comp8_rate_percent_diff
# click_bool
# gross_bookings_usd
# booking_bool

# %%
for column in df_filtered.columns[30:35]:
    print(column)
    plt.figure(figsize=(10, 4))
    sns.histplot(df_filtered[column].dropna(), kde=False)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
    print(df[column].describe())

# %%
# Check for all bool or flag type columns 0 or 1
bool_columns = [col for col in df.columns if 'bool' in col or 'flag' in col]
for column in bool_columns:
    print(df[column].value_counts())
# Out:
# prop_brand_bool
# 1    3147060
# 0    1811287
# Name: count, dtype: int64
# promotion_flag
# 0    3889229
# 1    1069118
# Name: count, dtype: int64
# srch_saturday_night_bool
# 1    2490145
# 0    2468202
# Name: count, dtype: int64
# random_bool
# 0    3491170
# 1    1467177
# Name: count, dtype: int64
# click_bool
# 0    4736468
# 1     221879
# Name: count, dtype: int64
# booking_bool
# 0    4819957
# 1     138390
# Name: count, dtype: int64

# %%
# check visitor_hist_starrating prop_starrating prop_review_score all between 0-5
rating_columns = ['visitor_hist_starrating', 'prop_starrating', 'prop_review_score']
for column in rating_columns:
    if df[column].max() > 5 or df[column].min() < 0:
        print(f'{column} has values outside of the 0-5 range')
    else:
        print(f'{column} is within the 0-5 range')
# Out:
# visitor_hist_starrating is within the 0-5 range
# prop_starrating is within the 0-5 range
# prop_review_score is within the 0-5 range

# %%
# Check for negative values in all columns except _id variables and comp variables and srch_query_affinity_scor
columns_to_check = df.columns[
    ~df.columns.str.contains('_id') & 
    (df.columns != 'srch_query_affinity_score') & 
    ~df.columns.str.startswith('comp')
]
columns_flaws = [] # track columns containing negative values wrongly
# 对这些列进行检查
for column in columns_to_check:
    if df[column].dtype in ['int64', 'float64'] and (df[column] < 0).any():
        print(f"Column '{column}' contains values < 0.")
        columns_flaws.append(column)       
    else:
        print(f"All values in column '{column}' are > 0.")
print(columns_flaws)
# Out:
# All values in column 'date_time' are > 0.
# All values in column 'visitor_hist_starrating' are > 0.
# All values in column 'visitor_hist_adr_usd' are > 0.
# All values in column 'prop_starrating' are > 0.
# All values in column 'prop_review_score' are > 0.
# All values in column 'prop_brand_bool' are > 0.
# All values in column 'prop_location_score1' are > 0.
# All values in column 'prop_location_score2' are > 0.
# All values in column 'prop_log_historical_price' are > 0.
# All values in column 'position' are > 0.
# All values in column 'price_usd' are > 0.
# All values in column 'promotion_flag' are > 0.
# All values in column 'srch_length_of_stay' are > 0.
# All values in column 'srch_booking_window' are > 0.
# All values in column 'srch_adults_count' are > 0.
# All values in column 'srch_children_count' are > 0.
# All values in column 'srch_room_count' are > 0.
# All values in column 'srch_saturday_night_bool' are > 0.
# All values in column 'orig_destination_distance' are > 0.
# All values in column 'random_bool' are > 0.
# All values in column 'click_bool' are > 0.
# All values in column 'gross_bookings_usd' are > 0.
# All values in column 'booking_bool' are > 0.
# []

# %%
# Check for all _rate variables whether only contains 0,-1,1
comp_rate_columns = df.columns[df.columns.str.endswith('_rate')]
for column in comp_rate_columns:
    print(df[column].value_counts())
# Out:
# comp1_rate
#  1.0    67256
#  0.0    42959
# -1.0     9715
# Name: count, dtype: int64
# comp2_rate
#  0.0    1613590
#  1.0     250276
# -1.0     160806
# Name: count, dtype: int64
# comp3_rate
#  0.0    1212580
#  1.0     174118
# -1.0     147590
# Name: count, dtype: int64
# comp4_rate
#  0.0    204349
# -1.0     54057
#  1.0     48972
# Name: count, dtype: int64
# comp5_rate
#  0.0    1616232
#  1.0     328268
# -1.0     277873
# Name: count, dtype: int64
# comp6_rate
#  0.0    160932
#  1.0     55022
# -1.0     24203
# Name: count, dtype: int64
# comp7_rate
#  0.0    203203
#  1.0     79088
# -1.0     33057
# Name: count, dtype: int64
# comp8_rate
#  0.0    1487647
# -1.0     272865
#  1.0     156142
# Name: count, dtype: int64

# %% [markdown]
# ## Outliers

# %% [markdown]
# From the distribution plots above, personally speaking, I feel only in price varaibles has this issue. But I am not sure whether we should adjust this.

# %%
to_check_columns = ['visitor_hist_adr_usd', 'prop_log_historical_price', 'price_usd', 'srch_length_of_stay', 'srch_booking_window', 
                    'srch_adults_count', 'srch_children_count', 'srch_room_count', 
                    'srch_query_affinity_score', 'orig_destination_distance']

def detect_outliers(df, numeric_columns):
    outliers = {}
    for column in numeric_columns:
        if df[column].dtype in ['float64', 'int64']:  # 确保处理的是数值类型的列
            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1
            outlier_condition = ((df[column] < (Q1 - 1.5 * IQR)) | (df[column] > (Q3 + 1.5 * IQR)))
            outliers[column] = df[outlier_condition]
    return outliers

outlier_data = detect_outliers(df, to_check_columns)

for column, data in outlier_data.items():
    print(f"Number of outliers in {column}: {data.shape[0]}")
    # calculate the percentage of outliers in the column(not NA count)
    print(f"Percentage of outliers in {column}: {data.shape[0] / df[column].count() * 100:.2f}%")
# Out:
# Number of outliers in visitor_hist_adr_usd: 11364
# Percentage of outliers in visitor_hist_adr_usd: 4.49%
# Number of outliers in prop_location_score1: 0
# Percentage of outliers in prop_location_score1: 0.00%
# Number of outliers in prop_location_score2: 271139
# Percentage of outliers in prop_location_score2: 7.01%
# Number of outliers in prop_log_historical_price: 715654
# Percentage of outliers in prop_log_historical_price: 14.43%
# Number of outliers in position: 0
# Percentage of outliers in position: 0.00%
# Number of outliers in price_usd: 294480
# Percentage of outliers in price_usd: 5.94%
# Number of outliers in srch_length_of_stay: 231907
# Percentage of outliers in srch_length_of_stay: 4.68%
# Number of outliers in srch_booking_window: 423510
# Percentage of outliers in srch_booking_window: 8.54%
# Number of outliers in srch_adults_count: 1712113
# Percentage of outliers in srch_adults_count: 34.53%
# Number of outliers in srch_children_count: 1146573
# Percentage of outliers in srch_children_count: 23.12%
# Number of outliers in srch_room_count: 438135
# Percentage of outliers in srch_room_count: 8.84%
# Number of outliers in srch_query_affinity_score: 12299
# Percentage of outliers in srch_query_affinity_score: 3.87%
# Number of outliers in orig_destination_distance: 417607
# Percentage of outliers in orig_destination_distance: 12.46%

# %% [markdown]
# ### vistor_hist_adr_usd

# %%
# plot the distribution of the vistor_hist_adr_usd column
plt.figure(figsize=(10, 4))
sns.histplot(df['visitor_hist_adr_usd'].dropna(), kde=False)

# describe
print(df['visitor_hist_adr_usd'].describe())

# print outliers upper bound and lower bound
Q1 = df['visitor_hist_adr_usd'].quantile(0.25)
Q3 = df['visitor_hist_adr_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(f"Lower bound: {lower_bound}, Upper bound: {upper_bound}")
print(f"Number of outliers above upper bound: {df[df['visitor_hist_adr_usd'] > upper_bound].shape[0]}")
print(f"proportion of outliers above upper bound: {df[df['visitor_hist_adr_usd'] > upper_bound].shape[0] / df['visitor_hist_adr_usd'].count() * 100:.2f}%")
# Out:
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    252988.000000
# mean        176.022659
# std         107.254493
# min           0.000000
# 25%         109.810000
# 50%         152.240000
# 75%         213.490000
# max        1958.700000
# Name: visitor_hist_adr_usd, dtype: float64
# Lower bound: -45.71000000000001, Upper bound: 369.01
# Number of outliers above upper bound: 11364
# proportion of outliers above upper bound: 4.49%

# %%
# make data bigger than upper bound equal to upper bound
df.loc[df['visitor_hist_adr_usd'] > upper_bound, 'visitor_hist_adr_usd'] = upper_bound

# %% [markdown]
# ### 'srch_length_of_stay', 'srch_booking_window', 'srch_adults_count', 'srch_children_count', 'srch_room_count', 'srch_query_affinity_score', 'orig_destination_distance'

# %%
colunms = ['srch_length_of_stay', 'srch_booking_window', 'srch_adults_count', 'srch_children_count', 'srch_room_count', 
           'srch_query_affinity_score', 'orig_destination_distance']

for i in colunms:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[i].dropna(), kde=False)
    plt.title(f'Distribution of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.show()
    print(df[i].describe())
    
# print outliers upper and lower bound
for column in colunms:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    print(f"Column: {column}")
    print(f"Lower bound: {lower_bound}, Upper bound: {upper_bound}")
    print(f"Number of outliers above upper bound: {df[df[column] > upper_bound].shape[0]}")
    print(f"proportion of outliers above upper bound: {df[df[column] > upper_bound].shape[0] / df[column].count() * 100:.2f}%")
    print(f"Number of outliers below lower bound: {df[df[column] < lower_bound].shape[0]}")
    print(f"proportion of outliers below lower bound: {df[df[column] < lower_bound].shape[0] / df[column].count() * 100:.2f}%")
    print("\n")
# Out:
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    4.958347e+06
# mean     2.385427e+00
# std      2.053243e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      5.700000e+01
# Name: srch_length_of_stay, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    4.958347e+06
# mean     3.747417e+01
# std      5.199341e+01
# min      0.000000e+00
# 25%      4.000000e+00
# 50%      1.700000e+01
# 75%      4.800000e+01
# max      4.920000e+02
# Name: srch_booking_window, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    4.958347e+06
# mean     1.972637e+00
# std      8.570628e-01
# min      1.000000e+00
# 25%      2.000000e+00
# 50%      2.000000e+00
# 75%      2.000000e+00
# max      9.000000e+00
# Name: srch_adults_count, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    4.958347e+06
# mean     3.504918e-01
# std      7.325692e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.000000e+00
# Name: srch_children_count, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    4.958347e+06
# mean     1.110525e+00
# std      4.172290e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      8.000000e+00
# Name: srch_room_count, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    317406.000000
# mean        -24.146418
# std          15.743238
# min        -326.567500
# 25%         -30.774775
# 50%         -20.451300
# 75%         -13.350625
# max          -2.494100
# Name: srch_query_affinity_score, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    3.350565e+06
# mean     1.301234e+03
# std      2.023951e+03
# min      1.000000e-02
# 25%      1.398000e+02
# 50%      3.866000e+02
# 75%      1.500670e+03
# max      1.166664e+04
# Name: orig_destination_distance, dtype: float64
# Column: srch_length_of_stay
# Lower bound: -2.0, Upper bound: 6.0
# Number of outliers above upper bound: 231907
# proportion of outliers above upper bound: 4.68%
# Number of outliers below lower bound: 0
# proportion of outliers below lower bound: 0.00%
#
#
# Column: srch_booking_window
# Lower bound: -62.0, Upper bound: 114.0
# Number of outliers above upper bound: 423510
# proportion of outliers above upper bound: 8.54%
# Number of outliers below lower bound: 0
# proportion of outliers below lower bound: 0.00%
#
#
# Column: srch_adults_count
# Lower bound: 2.0, Upper bound: 2.0
# Number of outliers above upper bound: 555252
# proportion of outliers above upper bound: 11.20%
# Number of outliers below lower bound: 1156861
# proportion of outliers below lower bound: 23.33%
#
#
# Column: srch_children_count
# Lower bound: 0.0, Upper bound: 0.0
# Number of outliers above upper bound: 1146573
# proportion of outliers above upper bound: 23.12%
# Number of outliers below lower bound: 0
# proportion of outliers below lower bound: 0.00%
#
#
# Column: srch_room_count
# Lower bound: 1.0, Upper bound: 1.0
# Number of outliers above upper bound: 438135
# proportion of outliers above upper bound: 8.84%
# Number of outliers below lower bound: 0
# proportion of outliers below lower bound: 0.00%
#
#
# Column: srch_query_affinity_score
# Lower bound: -56.910999999999994, Upper bound: 12.785599999999995
# Number of outliers above upper bound: 0
# proportion of outliers above upper bound: 0.00%
# Number of outliers below lower bound: 12299
# proportion of outliers below lower bound: 3.87%
#
#
# Column: orig_destination_distance
# Lower bound: -1901.5050000000003, Upper bound: 3541.9750000000004
# Number of outliers above upper bound: 417607
# proportion of outliers above upper bound: 12.46%
# Number of outliers below lower bound: 0
# proportion of outliers below lower bound: 0.00%

# %%
# for srch_query_affinity_score, make data smaller than lower bound equal to lower bound
Q1 = df['srch_query_affinity_score'].quantile(0.25)
Q3 = df['srch_query_affinity_score'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 2 * IQR # why 2 not 1.5: to make the distribution figure the smallest score not takes the highest frequency
upper_bound = Q3 + 1.5 * IQR
print(f"Lower bound: {lower_bound}, Upper bound: {upper_bound}")
print(f"Number of outliers below lower bound: {df[df['srch_query_affinity_score'] < lower_bound].shape[0]}")
print(f"proportion of outliers below lower bound: {df[df['srch_query_affinity_score'] < lower_bound].shape[0] / df['srch_query_affinity_score'].count() * 100:.2f}%")

df.loc[df['srch_query_affinity_score'] < lower_bound, 'srch_query_affinity_score'] = lower_bound
# Out:
# Lower bound: -65.623075, Upper bound: 12.785599999999995
# Number of outliers below lower bound: 6548
# proportion of outliers below lower bound: 2.06%

# %% [markdown]
# ### price_usd

# %%
# print describe
print(df['price_usd'].describe())

# print outliers upper and lower bound
Q1 = df['price_usd'].quantile(0.25)
Q3 = df['price_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 3 * IQR # 484.84000000000003 makes sense for rich people
print(f"Lower bound: {lower_bound}, Upper bound: {upper_bound}")
print(f"Number of outliers above upper bound: {df[df['price_usd'] > upper_bound].shape[0]}")
print(f"proportion of outliers above upper bound: {df[df['price_usd'] > upper_bound].shape[0] / df['price_usd'].count() * 100:.2f}%")
# Out:
# count    4.958347e+06
# mean     2.542096e+02
# std      1.600124e+04
# min      0.000000e+00
# 25%      8.500000e+01
# 50%      1.220000e+02
# 75%      1.849600e+02
# max      1.972633e+07
# Name: price_usd, dtype: float64
# Lower bound: -64.94, Upper bound: 484.84000000000003
# Number of outliers above upper bound: 97898
# proportion of outliers above upper bound: 1.97%

# %%
# make data bigger than upper bound equal to upper bound
df.loc[df['price_usd'] > upper_bound, 'price_usd'] = upper_bound

# %% [markdown]
# ## Missing Values

# %%
# Get the amount of missing values of each column
missing_values = df.isnull().sum()
missing_values
# Out:
# srch_id                              0
# date_time                            0
# site_id                              0
# visitor_location_country_id          0
# visitor_hist_starrating        4706481
# visitor_hist_adr_usd           4705359
# prop_country_id                      0
# prop_id                              0
# prop_starrating                      0
# prop_review_score                 7364
# prop_brand_bool                      0
# prop_location_score1                 0
# prop_location_score2           1090348
# prop_log_historical_price            0
# position                             0
# price_usd                            0
# promotion_flag                       0
# srch_destination_id                  0
# srch_length_of_stay                  0
# srch_booking_window                  0
# srch_adults_count                    0
# srch_children_count                  0
# srch_room_count                      0
# srch_saturday_night_bool             0
# srch_query_affinity_score      4640941
# orig_destination_distance      1607782
# random_bool                          0
# comp1_rate                     4838417
# comp1_inv                      4828788
# comp1_rate_percent_diff        4863908
# comp2_rate                     2933675
# comp2_inv                      2828078
# comp2_rate_percent_diff        4402109
# comp3_rate                     3424059
# comp3_inv                      3307357
# comp3_rate_percent_diff        4485550
# comp4_rate                     4650969
# comp4_inv                      4614684
# comp4_rate_percent_diff        4827261
# comp5_rate                     2735974
# comp5_inv                      2598327
# comp5_rate_percent_diff        4117248
# comp6_rate                     4718190
# comp6_inv                      4697371
# comp6_rate_percent_diff        4862173
# comp7_rate                     4642999
# comp7_inv                      4601925
# comp7_rate_percent_diff        4819832
# comp8_rate                     3041693
# comp8_inv                      2970844
# comp8_rate_percent_diff        4343617
# click_bool                           0
# gross_bookings_usd             4819957
# booking_bool                         0
# dtype: int64

# %% [markdown]
# A hypothesis was that users do not like to book hotels with missing values, consequently
# missing values were filled with worst case scenario. The missing values of competitor
# descriptions were all set to zero.

# %% [markdown]
# ### prop_review_score

# %%
# check prop_review_score min,max,mean,median and plot its distribution
print(df['prop_review_score'].describe())
sns.histplot(df['prop_review_score'], kde=True)

df['prop_review_score'] = df['prop_review_score'].fillna(0)
# Out:
# count    4.950983e+06
# mean     3.777777e+00
# std      1.050329e+00
# min      0.000000e+00
# 25%      3.500000e+00
# 50%      4.000000e+00
# 75%      4.500000e+00
# max      5.000000e+00
# Name: prop_review_score, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### comp_

# %%
# for all comp variables, set the missing values to 0.
comp_cols = [f'comp{i}_rate' for i in range(1, 9)]
comp_cols += [f'comp{i}_inv' for i in range(1, 9)]
comp_cols += [f'comp{i}_rate_percent_diff' for i in range(1, 9)]
df[comp_cols] = df[comp_cols].fillna(0)




missing_values = df.isnull().sum()
missing_values
# Out:
# srch_id                              0
# date_time                            0
# site_id                              0
# visitor_location_country_id          0
# visitor_hist_starrating        4706481
# visitor_hist_adr_usd           4705359
# prop_country_id                      0
# prop_id                              0
# prop_starrating                      0
# prop_review_score                    0
# prop_brand_bool                      0
# prop_location_score1                 0
# prop_location_score2           1090348
# prop_log_historical_price            0
# position                             0
# price_usd                            0
# promotion_flag                       0
# srch_destination_id                  0
# srch_length_of_stay                  0
# srch_booking_window                  0
# srch_adults_count                    0
# srch_children_count                  0
# srch_room_count                      0
# srch_saturday_night_bool             0
# srch_query_affinity_score      4640941
# orig_destination_distance      1607782
# random_bool                          0
# comp1_rate                           0
# comp1_inv                            0
# comp1_rate_percent_diff              0
# comp2_rate                           0
# comp2_inv                            0
# comp2_rate_percent_diff              0
# comp3_rate                           0
# comp3_inv                            0
# comp3_rate_percent_diff              0
# comp4_rate                           0
# comp4_inv                            0
# comp4_rate_percent_diff              0
# comp5_rate                           0
# comp5_inv                            0
# comp5_rate_percent_diff              0
# comp6_rate                           0
# comp6_inv                            0
# comp6_rate_percent_diff              0
# comp7_rate                           0
# comp7_inv                            0
# comp7_rate_percent_diff              0
# comp8_rate                           0
# comp8_inv                            0
# comp8_rate_percent_diff              0
# click_bool                           0
# gross_bookings_usd             4819957
# booking_bool                         0
# dtype: int64

# %% [markdown]
# ### prop_location_score2

# %%
# check the prop_location_score2 variable min,max,mean,median and plot its distribution
print(df['prop_location_score2'].describe())
sns.histplot(df['prop_location_score2'], bins=50)
# Out:
# count    3.867999e+06
# mean     1.303852e-01
# std      1.594634e-01
# min      0.000000e+00
# 25%      1.900000e-02
# 50%      6.900000e-02
# 75%      1.805000e-01
# max      1.000000e+00
# Name: prop_location_score2, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='prop_location_score2', ylabel='Count'>

# %%
# fill NA in prop_location_score2 with 0
df['prop_location_score2'] = df['prop_location_score2'].fillna(0)

# %% [markdown]
# ### srch_query_affinity_score

# %%
# check srch_query_affinity_score variable min,max,mean,median and plot its distribution
print(df['srch_query_affinity_score'].describe())
sns.histplot(df['srch_query_affinity_score'], bins=50)
# Out:
# count    317406.000000
# mean        -23.775509
# std          14.029979
# min         -65.623075
# 25%         -30.774775
# 50%         -20.451300
# 75%         -13.350625
# max          -2.494100
# Name: srch_query_affinity_score, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='srch_query_affinity_score', ylabel='Count'>

# %%
# fill NA in srch_query_affinity_score with 5 times min
min_val = df['srch_query_affinity_score'].min()
df['srch_query_affinity_score'] = df['srch_query_affinity_score'].fillna(5*min_val)

# %% [markdown]
# ### orig_destination_distance

# %%
# check orig_destination_distance variable min,max,mean,median and plot its distribution
print(df['orig_destination_distance'].describe())
sns.histplot(df['orig_destination_distance'], bins=50)
# Out:
# count    3.350565e+06
# mean     1.301234e+03
# std      2.023951e+03
# min      1.000000e-02
# 25%      1.398000e+02
# 50%      3.866000e+02
# 75%      1.500670e+03
# max      1.166664e+04
# Name: orig_destination_distance, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='orig_destination_distance', ylabel='Count'>

# %%
# fill NA in orig_destination_distance with 10 times max
max_val = df['orig_destination_distance'].max()
df['orig_destination_distance'] = df['orig_destination_distance'].fillna(10*max_val) # 10 times max

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# srch_id                              0
# date_time                            0
# site_id                              0
# visitor_location_country_id          0
# visitor_hist_starrating        4706481
# visitor_hist_adr_usd           4705359
# prop_country_id                      0
# prop_id                              0
# prop_starrating                      0
# prop_review_score                    0
# prop_brand_bool                      0
# prop_location_score1                 0
# prop_location_score2                 0
# prop_log_historical_price            0
# position                             0
# price_usd                            0
# promotion_flag                       0
# srch_destination_id                  0
# srch_length_of_stay                  0
# srch_booking_window                  0
# srch_adults_count                    0
# srch_children_count                  0
# srch_room_count                      0
# srch_saturday_night_bool             0
# srch_query_affinity_score            0
# orig_destination_distance            0
# random_bool                          0
# comp1_rate                           0
# comp1_inv                            0
# comp1_rate_percent_diff              0
# comp2_rate                           0
# comp2_inv                            0
# comp2_rate_percent_diff              0
# comp3_rate                           0
# comp3_inv                            0
# comp3_rate_percent_diff              0
# comp4_rate                           0
# comp4_inv                            0
# comp4_rate_percent_diff              0
# comp5_rate                           0
# comp5_inv                            0
# comp5_rate_percent_diff              0
# comp6_rate                           0
# comp6_inv                            0
# comp6_rate_percent_diff              0
# comp7_rate                           0
# comp7_inv                            0
# comp7_rate_percent_diff              0
# comp8_rate                           0
# comp8_inv                            0
# comp8_rate_percent_diff              0
# click_bool                           0
# gross_bookings_usd             4819957
# booking_bool                         0
# dtype: int64

# %% [markdown]
# ### visitor_hist_starrating and visitor_hist_adr_usd

# %%
# for visitor_hist_starrating and visitor_hist_adr_usd, check if one is null the other is also null
both_nulls = df[df['visitor_hist_starrating'].isnull() & df['visitor_hist_adr_usd'].isnull()]

# calculate the number of nulls in each of these 2 columns
nulls_star = df['visitor_hist_starrating'].isnull().sum()
nulls_usd = df['visitor_hist_adr_usd'].isnull().sum()


percentage_matching_nulls = (both_nulls.shape[0] / df.shape[0]) * 100
percentage_matching_nulls_stars = (both_nulls.shape[0] / nulls_star) * 100
percentage_matching_nulls_usd = (both_nulls.shape[0] / nulls_usd) * 100

print(f'Percentage of matching nulls: {percentage_matching_nulls}')
print(f'Percentage of matching nulls in visitor_hist_starrating: {percentage_matching_nulls_stars}')
print(f'Percentage of matching nulls in visitor_hist_adr_usd: {percentage_matching_nulls_usd}')
# Out:
# Percentage of matching nulls: 94.897069527405
# Percentage of matching nulls in visitor_hist_starrating: 99.97545937187465
# Percentage of matching nulls in visitor_hist_adr_usd: 99.99929867200356

# %% [markdown]
# We assume that nulls in visitor_hist_starrating and visitor_hist_adr_usd should be identical. If not, we assume that this is a flaw. And we treat the non-null as null.

# %%
# Add a column 'bool_visitor_hist' to suggest whether either in visitor_hist_starrating or visitor_hist_adr_usd is null. 
# If both is not null, 'bool_visitor_hist' = 1. In other cases 'bool_visitor_hist' = 0.
df['bool_visitor_hist'] = 1
df.loc[df['visitor_hist_starrating'].isnull() | df['visitor_hist_adr_usd'].isnull(), 'bool_visitor_hist'] = 0

# %%
# Check 'visitor_hist_starrating' and 'visitor_hist_adr_usd' min,max,mean,median and plot their distribution
print(df['visitor_hist_starrating'].describe())
sns.histplot(df['visitor_hist_starrating'], bins=50)
# Out:
# count    251866.000000
# mean          3.374334
# std           0.692519
# min           1.410000
# 25%           2.920000
# 50%           3.450000
# 75%           3.930000
# max           5.000000
# Name: visitor_hist_starrating, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='visitor_hist_starrating', ylabel='Count'>

# %%
print(df['visitor_hist_adr_usd'].describe())
sns.histplot(df['visitor_hist_adr_usd'], bins=50)
# Out:
# count    252988.000000
# mean        169.646320
# std          80.984001
# min           0.000000
# 25%         109.810000
# 50%         152.240000
# 75%         213.490000
# max         369.010000
# Name: visitor_hist_adr_usd, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='visitor_hist_adr_usd', ylabel='Count'>

# %% [markdown]
# Seems like visitor_hist_starrating and visitor_hist_adr_usd has no 0.  Now We make them both 0 if either one of them is null.

# %%
# If bool_visitor_hist is 0, make both visitor_hist_starrating and visitor_hist_adr_usd's values 0
df.loc[df['bool_visitor_hist'] == 0, 'visitor_hist_starrating'] = 0
df.loc[df['bool_visitor_hist'] == 0, 'visitor_hist_adr_usd'] = 0

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# srch_id                              0
# date_time                            0
# site_id                              0
# visitor_location_country_id          0
# visitor_hist_starrating              0
# visitor_hist_adr_usd                 0
# prop_country_id                      0
# prop_id                              0
# prop_starrating                      0
# prop_review_score                    0
# prop_brand_bool                      0
# prop_location_score1                 0
# prop_location_score2                 0
# prop_log_historical_price            0
# position                             0
# price_usd                            0
# promotion_flag                       0
# srch_destination_id                  0
# srch_length_of_stay                  0
# srch_booking_window                  0
# srch_adults_count                    0
# srch_children_count                  0
# srch_room_count                      0
# srch_saturday_night_bool             0
# srch_query_affinity_score            0
# orig_destination_distance            0
# random_bool                          0
# comp1_rate                           0
# comp1_inv                            0
# comp1_rate_percent_diff              0
# comp2_rate                           0
# comp2_inv                            0
# comp2_rate_percent_diff              0
# comp3_rate                           0
# comp3_inv                            0
# comp3_rate_percent_diff              0
# comp4_rate                           0
# comp4_inv                            0
# comp4_rate_percent_diff              0
# comp5_rate                           0
# comp5_inv                            0
# comp5_rate_percent_diff              0
# comp6_rate                           0
# comp6_inv                            0
# comp6_rate_percent_diff              0
# comp7_rate                           0
# comp7_inv                            0
# comp7_rate_percent_diff              0
# comp8_rate                           0
# comp8_inv                            0
# comp8_rate_percent_diff              0
# click_bool                           0
# gross_bookings_usd             4819957
# booking_bool                         0
# bool_visitor_hist                    0
# dtype: int64

# %% [markdown]
# ### gross_bookings_usd

# %%
# check gross_bookings_usd missing value percentage and plot its distribution
missing_gross_bookings = df['gross_bookings_usd'].isnull().sum()
percentage_missing_gross_bookings = (missing_gross_bookings / df.shape[0]) * 100
print(f'Percentage of missing values in gross_bookings_usd: {percentage_missing_gross_bookings}')

print(df['gross_bookings_usd'].describe())
sns.histplot(df['gross_bookings_usd'], bins=50)
# Out:
# Percentage of missing values in gross_bookings_usd: 97.20894886945186
# count    138390.000000
# mean        386.283316
# std         821.190577
# min           0.000000
# 25%         124.000000
# 50%         218.400000
# 75%         429.790000
# max      159292.380000
# Name: gross_bookings_usd, dtype: float64
# /Users/eva/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='gross_bookings_usd', ylabel='Count'>

# %%
# if booking_bool is 1, check whether gross_bookings_usd is null. Should be 0.
booking_bool = df[df['booking_bool'] == 1]
missing_gross_bookings_booking = booking_bool['gross_bookings_usd'].isnull().sum()
print(missing_gross_bookings_booking)

#if booking_bool is 0, check whether gross_bookings_usd is null. Should be 100.
booking_bool = df[df['booking_bool'] == 0]
missing_gross_bookings_nonbooking = booking_bool['gross_bookings_usd'].isnull().sum()
percentage_gross_bookings_nonbooking = (missing_gross_bookings_nonbooking / booking_bool.shape[0]) * 100
print(percentage_gross_bookings_nonbooking)

# if booking_bool is 1, check whether gross_bookings_usd is 0. Should be 0.
booking_bool = df[df['booking_bool'] == 1]
zero_gross_bookings_booking = booking_bool[booking_bool['gross_bookings_usd'] == 0].shape[0]
print(zero_gross_bookings_booking)

# if booking_bool is 0, check whether gross_bookings_usd is 0. Should be 0.
booking_bool = df[df['booking_bool'] == 0]
zero_gross_bookings_nonbooking = booking_bool[booking_bool['gross_bookings_usd'] == 0].shape[0]
percentage_zero_gross_bookings_nonbooking = (zero_gross_bookings_nonbooking / booking_bool.shape[0]) * 100
print(percentage_zero_gross_bookings_nonbooking)
# Out:
# 0
# 100.0
# 24
# 0.0

# %%
# check price_usd describe
print(df['price_usd'].describe())
# Out:
# count    4.958347e+06
# mean     1.499354e+02
# std      9.496754e+01
# min      0.000000e+00
# 25%      8.500000e+01
# 50%      1.220000e+02
# 75%      1.849600e+02
# max      4.848400e+02
# Name: price_usd, dtype: float64

# %%
# make NA in gross_bookings_usd 0
df['gross_bookings_usd'] = df['gross_bookings_usd'].fillna(0)

# %%
df.to_csv('/Users/eva/Documents/Study/Y1S2/DMT/assignment2/cleaned_training_set_VU_DM.csv', index=False)

# %% [markdown]
# # Summary of data cleaning
# - wrong data:
#   - Check all bool and flag data all 0 or 1.
#   - Check all comp{i}_rate all 0, -1, 1.
#   - Check all non-negative variables all >=0.
#   - Check all starrating or score variables all between 0 and 5.
# - Outliers:
#   - Check for price_usd: upper bound using q3+3*iqr (484), makes sense for rich people. Make data bigger than upper bound = upper bound.
#   - Check for 'srch_query_affinity_score': lower bound using q1-2*iqr, make the distribution plot the smallest x takes not the highest account. Make data lower than lower bound = lower bound.
#   - Check for 'visitor_hist_adr_usd': upper bound using q3+1.5*iqr. Make data bigger than upper bound = upper bound.
# - missing data:
#   - A hypothesis was that users do not like to book hotels with missing values, consequently missing values were filled with worst case scenario.
#     - for 'prop_location_score2' and 'prop_review_score', set null 0.
#     - for 'srch_query_affinity_score'(all negative values), set null 5*min.(dont want negative values too small)
#     - for 'orig_destination_distance', set null 10*max.
#   - The missing values of competitor descriptions were all set to zero.
#   - For 'visitor_hist_adr_usd' and 'visitor_hist_starrating', their nulls are not identical. We add a column 'bool_visitor_hist' to suggest whether either in 'visitor_hist_starrating' or 'visitor_hist_adr_usd' is null. If 'bool_visitor_hist' is 0, make both 'visitor_hist_starrating' and 'visitor_hist_adr_usd''s values 0.
#   - For 'gross_bookings_usd', in chunk_0 data, it seems that it's perfectly matched with 'booking_bool'. However one 0 in 'gross_bookings_usd' is identicied when 'booking_bool' is 1. This is a flaw. We make all NA in 'gross_bookings_usd' 0.
# - Outliers:
#   -
